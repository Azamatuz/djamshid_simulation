# %%
import pandas as pd
import numpy as np
from random import shuffle
import matplotlib.pyplot as plt
# %matplotlib inline

# Import charting libraries
import seaborn as sns
plt.rc("font", size=14)
import seaborn as sns
sns.set(style="white") #white background style for seaborn plots
sns.set(style="whitegrid", color_codes=True)

import matplotlib.font_manager as fm

# %%
# strategies listed here. change strategies as needed
teachers = ['coop', 'def', 'tit1', 'tit0' , 'disap']*20

# %%
# the main logic of algorithm. do not change!
shuffle(teachers)
df = pd.DataFrame(columns=teachers, index=teachers)

df[:] = 'empty'
coop_status = 'C'
def_status = 'D'
tit1_status = 'C'
tit0_status = 'C'
disap_status = 'C'
disap_status_horizon = 'C'

for i in range(len(teachers)):
    for j in range(len(teachers)):
        if i == j:
            df.iloc[i][j] = '0, 0'
        else:
            # coop
            if df.columns[i] == 'coop':
                if df.index[j] == 'coop':
                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=coop_status,
                                                                        status_two=coop_status)
                if df.index[j] == 'def':
                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=coop_status,
                                                                        status_two=def_status)
                if df.index[j] == 'tit1':
                    if df.iloc[i-1][j][-1] == '0' and df.iloc[i - 2][j][0] == 'D':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=coop_status,
                                                                            status_two='D')
                    if df.iloc[i - 1][j][0] == 'D':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=coop_status,
                                                                            status_two='D')
                    else:
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=coop_status,
                                                                            status_two=tit1_status)
                if df.index[j] == 'tit0':
                    if i == 0 or i == 1 and df.iloc[i-1][j][0] == '0':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=coop_status,
                                                                            status_two='D')
                    elif df.iloc[i - 1][j][0] == '0':
                        if df.iloc[i - 2][j][0] == 'D':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=coop_status,
                                                                                status_two='D')
                        else:
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=coop_status,
                                                                                status_two=tit0_status)
                    elif df.iloc[i - 1][j][0] == 'D':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=coop_status,
                                                                            status_two='D')
                    else:
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=coop_status,
                                                                            status_two=tit0_status)
                if df.index[j] == 'disap':
                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=coop_status,
                                                                        status_two=disap_status)

            # def
            if df.columns[i] == 'def':
                if df.index[j] == 'coop':
                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                        status_two=coop_status)
                if df.index[j] == 'def':
                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                        status_two=def_status)
                if df.index[j] == 'tit1':
                    if i == 0 or i == 1 and df.iloc[i-1][j][-1] == '0':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                            status_two=tit1_status)
                    else:
                        if df.iloc[i - 1][j][0] == '0':
                            if df.iloc[i - 2][j][0] == 'D':
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                                    status_two='D')
                            else:
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                                    status_two=tit1_status)
                        if df.iloc[i - 1][j][0] == 'D':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                                status_two='D')
                        else:
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                                status_two=tit1_status)
                if df.index[j] == 'tit0':
                    if i == 0 or i == 1 and df.iloc[i-1][j][-1] == '0':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                            status_two='D')
                    else:
                        if df.iloc[i - 1][j][0] == '0':
                            if df.iloc[i - 2][j][0] == 'D':
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                                    status_two='D')
                            else:
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                                    status_two=tit0_status)
                        if df.iloc[i - 1][j][0] == 'D':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                                status_two='D')
                        else:
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                                status_two=tit0_status)
                if df.index[j] == 'disap':
                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                        status_two=disap_status)
            # tit1
            if df.columns[i] == 'tit1':
                if df.iloc[i][j - 1][-1] == 'D' or df.iloc[i][j - 1][0] == '0' and df.iloc[i][j - 2][-1] == 'D':
                    if df.index[j] == 'coop':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                            status_two=coop_status)
                    if df.index[j] == 'def':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                            status_two=def_status)
                    if df.index[j] == 'tit1':
                        if i == 0 or i == 1 and df.iloc[i - 1][j][-1] == '0':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                status_two=tit1_status)
                        else:
                            if df.iloc[i - 1][j][0] == '0':
                                if df.iloc[i - 2][j][0] == 'D':
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                        status_two=not tit1_status)
                                else:
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                        status_two=tit1_status)
                            if df.iloc[i - 1][j][0] == 'D':
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                    status_two='D')
                            else:
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                    status_two=tit1_status)
                    if df.index[j] == 'tit0':
                        if i == 0 or i == 1 and df.iloc[i - 1][j][-1] == 'D':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                status_two='D')
                        else:
                            if df.iloc[i - 1][j][0] == '0':
                                if df.iloc[i - 2][j][0] == 'D':
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                        status_two='D')
                                else:
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                        status_two=tit0_status)
                            if df.iloc[i - 1][j][0] == 'D':
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                    status_two='D')
                            else:
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                    status_two=tit0_status)
                    if df.index[j] == 'disap':
                        if df.iloc[i - 2][j][0] == 'D' and df.iloc[i - 1][j][0] == 'D':
                            disap_status = 'D'
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                            status_two=disap_status)
                else:
                    if df.index[j] == 'coop':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit1_status,
                                                                            status_two=coop_status)
                    if df.index[j] == 'def':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit1_status,
                                                                            status_two=def_status)
                    if df.index[j] == 'tit1':
                        if i == 0 or i == 1 and df.iloc[i-1][j][-1] == '0':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit1_status,
                                                                                status_two=tit1_status)
                        else:
                            if df.iloc[i - 1][j][0] == '0':
                                if df.iloc[i - 2][j][0] == 'D':
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit1_status,
                                                                                        status_two='D')
                                else:
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit1_status,
                                                                                        status_two=tit1_status)
                            if df.iloc[i - 1][j][0] == 'D':
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit1_status,
                                                                                    status_two='D')
                            else:
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit1_status,
                                                                                    status_two=tit1_status)
                    if df.index[j] == 'tit0':
                        if i == 0 or i == 1 and df.iloc[i-1][j][-1] == '0':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit1_status,
                                                                                status_two='D')
                        elif df.iloc[i - 1][j][0] == '0' and df.iloc[i - 2][j][0] == 'D' or df.iloc[i - 1][j][0] == 'D':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit1_status,
                                                                                status_two='D')
                        else:
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit1_status,
                                                                                status_two=tit0_status)
                    if df.index[j] == 'disap':
                        if df.iloc[i - 2][j][0] == 'D' and df.iloc[i - 1][j][0] == 'D':
                            disap_status = 'D'
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit1_status,
                                                                            status_two=disap_status)
            # tit0
            if df.columns[i] == 'tit0':
                if j == 0 or j == 1 and df.iloc[i][j - 1][-1] == '0' \
                        or df.iloc[i][j - 1][0] == '0' and df.iloc[i][j - 2][-1] == 'D' or df.iloc[i][j - 1][-1] == 'D':
                    if df.index[j] == 'coop':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                            status_two=coop_status)
                    if df.index[j] == 'def':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                            status_two=def_status)
                    if df.index[j] == 'tit1':
                        if i == 0 or i == 1 and df.iloc[i - 1][j][-1] == '0':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                status_two=tit1_status)
                        else:
                            if df.iloc[i - 1][j][0] == '0':
                                if df.iloc[i - 2][j][0] == 'D':
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                        status_two=not tit1_status)
                                else:
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                        status_two=tit1_status)
                            if df.iloc[i - 1][j][0] == 'D':
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                    status_two='D')
                            else:
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                    status_two=tit1_status)
                    if df.index[j] == 'tit0':
                        if i == 0 or i == 1 and df.iloc[i - 1][j][-1] == 'D':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                status_two='D')
                        else:
                            if df.iloc[i - 1][j][0] == '0':
                                if df.iloc[i - 2][j][0] == 'D':
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                        status_two='D')
                                else:
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                        status_two=tit0_status)
                            if df.iloc[i - 1][j][0] == 'D':
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                    status_two='D')
                            else:
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                    status_two=tit0_status)
                    if df.index[j] == 'disap':
                        if df.iloc[i - 2][j][0] == 'D' and df.iloc[i - 1][j][0] == 'D':
                            disap_status = 'D'
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                            status_two=disap_status)
                else:
                    if df.index[j] == 'coop':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit0_status,
                                                                            status_two=coop_status)
                    if df.index[j] == 'def':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit0_status,
                                                                            status_two=def_status)
                    if df.index[j] == 'tit1':
                        if i == 0 or i == 1 and df.iloc[i - 1][j][-1] == '0':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit0_status,
                                                                                status_two=tit1_status)
                        else:
                            if df.iloc[i - 1][j][0] == '0':
                                if df.iloc[i - 2][j][0] == 'D':
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit0_status,
                                                                                        status_two='D')
                                else:
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit0_status,
                                                                                        status_two=tit1_status)
                            if df.iloc[i - 1][j][0] == 'D':
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit0_status,
                                                                                    status_two='D')
                            else:
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit0_status,
                                                                                    status_two=tit1_status)
                    if df.index[j] == 'tit0':
                        if i == 0 or i == 1 and df.iloc[i - 1][j][-1] == '0':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit0_status,
                                                                                status_two='D')
                        elif df.iloc[i - 1][j][0] == '0' and df.iloc[i - 2][j][0] == 'D' or df.iloc[i - 1][j][0] == 'D':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit0_status,
                                                                                status_two='D')
                        else:
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit0_status,
                                                                                status_two=tit0_status)
                    if df.index[j] == 'disap':
                        if df.iloc[i - 2][j][0] == 'D' and df.iloc[i - 1][j][0] == 'D':
                            disap_status = 'D'
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit0_status,
                                                                            status_two=disap_status)
            # disap
            if df.columns[i] == 'disap':
                if df.iloc[i][j - 2][-1] == 'D' and df.iloc[i][j - 1][-1] == 'D':
                    disap_status_horizon = 'D'
                if df.index[j] == 'coop':
                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=disap_status_horizon,
                                                                        status_two=coop_status)
                if df.index[j] == 'def':
                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=disap_status_horizon,
                                                                        status_two=def_status)
                if df.index[j] == 'tit1':
                    if df.iloc[i-1][j][-1] == '0' and df.iloc[i - 2][j][0] == 'D':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=disap_status_horizon,
                                                                            status_two='D')
                    if df.iloc[i - 1][j][0] == 'D':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=disap_status_horizon,
                                                                            status_two='D')
                    else:
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=disap_status_horizon,
                                                                            status_two=tit1_status)
                if df.index[j] == 'tit0':
                    if i == 0 or i == 1 and df.iloc[i-1][j][0] == '0':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=disap_status_horizon,
                                                                            status_two='D')
                    elif df.iloc[i - 1][j][0] == '0':
                        if df.iloc[i - 2][j][0] == 'D':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=disap_status_horizon,
                                                                                status_two='D')
                        else:
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=disap_status_horizon,
                                                                                status_two=tit0_status)
                    elif df.iloc[i - 1][j][0] == 'D':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=disap_status_horizon,
                                                                            status_two='D')
                    else:
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=disap_status_horizon,
                                                                            status_two=tit0_status)
                if df.index[j] == 'disap':
                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=disap_status_horizon,
                                                                        status_two=disap_status)

# %%
# save excel file of table with C and D
df.to_csv('df.csv') #change the file as you need. it overwrite the previouse one

# %%
incentive = 4 # change if needed
U, L, C, P = 6, 3, 0, 0  # change if needed
df_payoff = df.copy()
for i in range(len(teachers)):
    for j in range(len(teachers)):
        if df_payoff.iloc[i][j] == '0, 0':
            df_payoff.iloc[i][j] = 0
        if df_payoff.iloc[i][j] == 'C, C':
            df_payoff.iloc[i][j] = U + C + incentive - L
        if df_payoff.iloc[i][j] == 'C, D':
            df_payoff.iloc[i][j] = incentive - L
        if df_payoff.iloc[i][j] == 'D, C':
            df_payoff.iloc[i][j] = U
        if df_payoff.iloc[i][j] == 'D, D':
            df_payoff.iloc[i][j] = P

# %%
# save excel file of table with incentives
df_payoff.to_csv('df_payoff.csv') #change the file as you need. it overwrite the previouse one

# %%
data = df_payoff.groupby(df_payoff.index).sum()
data = data.T
data
# Out:
#         coop    def  disap   tit0   tit1
# tit0    62.0   48.0   49.0   48.0   74.0
# coop   133.0  120.0  121.0  128.0  129.0
# tit0    80.0   78.0   79.0   85.0   92.0
# tit0    62.0   60.0   61.0   59.0   60.0
# tit1    56.0   54.0   49.0   57.0   43.0
# ...      ...    ...    ...    ...    ...
# disap   26.0    0.0    0.0   26.0    7.0
# tit0    50.0   30.0   18.0   33.0   30.0
# tit1    50.0   36.0   30.0   53.0   40.0
# disap   26.0    0.0    0.0   26.0    7.0
# coop   133.0  120.0  120.0  123.0  120.0
#
# [100 rows x 5 columns]

# %%
sns.set(style="whitegrid")
tips = sns.load_dataset("tips")
tips
#ax = sns.boxplot(x=tips["total_bill"])
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Font Imports
heading_font = fm.FontProperties(fname='PlayfairDisplay-Regular.ttf', size=28)

subtitle_font = fm.FontProperties(fname='Roboto-Regular.ttf', size=18)

lable_font = fm.FontProperties(fname='Roboto-Regular.ttf', size=20)

# Color Themes
color_bg = '#FEF1E5'
darker_highlight = '#FBEADC'
lighter_highlight = '#ffffff'

plt.figure(figsize=(10,5))


data = df_payoff.groupby(df_payoff.index).sum()

sns.boxplot(x=data.coop)
ax.axhline(0, color="k", clip_on=False)
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light'
)
plt.text(x=118, y=-.6,s='Strategies Comparison (incentive=4)',fontproperties=heading_font, color="black")
#plt.text(x=0, y=0.4, s='Based on statistic per 90 minutes',fontproperties=subtitle_font,color='#524939')

#plt.text(x=20, y=-0.3, s='Data souce: fbref.com',fontproperties=subtitle_font, horizontalalignment='right',color='#524939')


plt.xlabel('Players', fontproperties=lable_font)
plt.ylabel('Pay offs', fontproperties=lable_font)
# Out:
# Text(0, 0.5, 'Pay offs')

# %%
# ploting the result
from matplotlib.font_manager import FontProperties

font = FontProperties()
font.set_family('serif')
font.set_name('Times New Roman')
font.set_style('italic')

data = df_payoff.groupby(df_payoff.index).sum()
fig, ax = plt.subplots(figsize=(18, 16), dpi= 80)
ax.set_title('Strategies Comparison (incentive=4)', fontsize=20) # change digit of incentive
ax.boxplot(data, labels=data.index)
ax.set_xlabel('Pay offs', fontsize='large', fontweight='bold')
ax.set_ylabel('Players', fontsize='large', fontweight='bold')
plt.show()

# %%
# this section with random incentives 
# do not worry about worning message
mu, sigma = 4, 2 # mean and standard deviation

U, L, C, P = 6, 3, 0, 0  # change if needed
df_payoff_random = df.copy()
for i in range(len(teachers)):
    for j in range(len(teachers)):
        incentive = np.around(np.random.normal(mu, sigma, 1), decimals=1) # change if needed
        if df_payoff_random.iloc[i][j] == '0, 0':
            df_payoff_random.iloc[i][j] = 0
        if df_payoff_random.iloc[i][j] == 'C, C':
            df_payoff_random.iloc[i][j] = U + C + abs(incentive[0]) - L
        if df_payoff_random.iloc[i][j] == 'C, D':
            df_payoff_random.iloc[i][j] = abs(incentive[0]) - L
        if df_payoff_random.iloc[i][j] == 'D, C':
            df_payoff_random.iloc[i][j] = U
        if df_payoff_random.iloc[i][j] == 'D, D':
            df_payoff_random.iloc[i][j] = P

# %%
# save excel file of table with Random incentives
df_payoff_random.to_csv('df_payoff_random.csv') #change the file as you need. it overwrite the previouse one

# %%
# ploting the result for Random incentives
# do not wory about error 
from matplotlib.font_manager import FontProperties

font = FontProperties()
font.set_family('serif')
font.set_name('Times New Roman')
font.set_style('italic')

data = df_payoff_random.groupby(df_payoff_random.index).sum()
fig, ax = plt.subplots(figsize=(18, 16), dpi= 80)
ax.set_title('Strategies Comparison (incentive=4)', fontsize=20) # change digit of incentive
ax.boxplot(data, labels=data.index)
ax.set_xlabel('Pay offs', fontsize='large', fontweight='bold')
ax.set_ylabel('Players', fontsize='large', fontproperties=font)
plt.show()
