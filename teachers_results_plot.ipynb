# %%
import pandas as pd
from random import shuffle
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# strategies listed here. change strategies as needed
teachers = ['coop', 'def', 'tit1', 'tit0']*25

# %%
# the main logic of algorithm. do not change!
shuffle(teachers)
df = pd.DataFrame(columns=teachers, index=teachers)

df[:] = 'empty'
coop_status = 'C'
def_status = 'D'
tit1_status = 'C'
tit0_status = 'C'
disap_status = 'C'
disap_status_horizon = 'C'

for i in range(len(teachers)):
    for j in range(len(teachers)):
        if i == j:
            df.iloc[i][j] = '0, 0'
        else:
            # coop
            if df.columns[i] == 'coop':
                if df.index[j] == 'coop':
                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=coop_status,
                                                                        status_two=coop_status)
                if df.index[j] == 'def':
                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=coop_status,
                                                                        status_two=def_status)
                if df.index[j] == 'tit1':
                    if df.iloc[i-1][j][-1] == '0' and df.iloc[i - 2][j][0] == 'D':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=coop_status,
                                                                            status_two='D')
                    if df.iloc[i - 1][j][0] == 'D':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=coop_status,
                                                                            status_two='D')
                    else:
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=coop_status,
                                                                            status_two=tit1_status)
                if df.index[j] == 'tit0':
                    if i == 0 or i == 1 and df.iloc[i-1][j][0] == '0':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=coop_status,
                                                                            status_two='D')
                    elif df.iloc[i - 1][j][0] == '0':
                        if df.iloc[i - 2][j][0] == 'D':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=coop_status,
                                                                                status_two='D')
                        else:
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=coop_status,
                                                                                status_two=tit0_status)
                    elif df.iloc[i - 1][j][0] == 'D':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=coop_status,
                                                                            status_two='D')
                    else:
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=coop_status,
                                                                            status_two=tit0_status)
                if df.index[j] == 'disap':
                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=coop_status,
                                                                        status_two=disap_status)

            # def
            if df.columns[i] == 'def':
                if df.index[j] == 'coop':
                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                        status_two=coop_status)
                if df.index[j] == 'def':
                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                        status_two=def_status)
                if df.index[j] == 'tit1':
                    if i == 0 or i == 1 and df.iloc[i-1][j][-1] == '0':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                            status_two=tit1_status)
                    else:
                        if df.iloc[i - 1][j][0] == '0':
                            if df.iloc[i - 2][j][0] == 'D':
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                                    status_two='D')
                            else:
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                                    status_two=tit1_status)
                        if df.iloc[i - 1][j][0] == 'D':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                                status_two='D')
                        else:
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                                status_two=tit1_status)
                if df.index[j] == 'tit0':
                    if i == 0 or i == 1 and df.iloc[i-1][j][-1] == '0':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                            status_two='D')
                    else:
                        if df.iloc[i - 1][j][0] == '0':
                            if df.iloc[i - 2][j][0] == 'D':
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                                    status_two='D')
                            else:
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                                    status_two=tit0_status)
                        if df.iloc[i - 1][j][0] == 'D':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                                status_two='D')
                        else:
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                                status_two=tit0_status)
                if df.index[j] == 'disap':
                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                        status_two=disap_status)
            # tit1
            if df.columns[i] == 'tit1':
                if df.iloc[i][j - 1][-1] == 'D' or df.iloc[i][j - 1][0] == '0' and df.iloc[i][j - 2][-1] == 'D':
                    if df.index[j] == 'coop':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                            status_two=coop_status)
                    if df.index[j] == 'def':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                            status_two=def_status)
                    if df.index[j] == 'tit1':
                        if i == 0 or i == 1 and df.iloc[i - 1][j][-1] == '0':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                status_two=tit1_status)
                        else:
                            if df.iloc[i - 1][j][0] == '0':
                                if df.iloc[i - 2][j][0] == 'D':
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                        status_two=not tit1_status)
                                else:
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                        status_two=tit1_status)
                            if df.iloc[i - 1][j][0] == 'D':
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                    status_two='D')
                            else:
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                    status_two=tit1_status)
                    if df.index[j] == 'tit0':
                        if i == 0 or i == 1 and df.iloc[i - 1][j][-1] == 'D':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                status_two='D')
                        else:
                            if df.iloc[i - 1][j][0] == '0':
                                if df.iloc[i - 2][j][0] == 'D':
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                        status_two='D')
                                else:
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                        status_two=tit0_status)
                            if df.iloc[i - 1][j][0] == 'D':
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                    status_two='D')
                            else:
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                    status_two=tit0_status)
                    if df.index[j] == 'disap':
                        if df.iloc[i - 2][j][0] == 'D' and df.iloc[i - 1][j][0] == 'D':
                            disap_status = 'D'
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                            status_two=disap_status)
                else:
                    if df.index[j] == 'coop':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit1_status,
                                                                            status_two=coop_status)
                    if df.index[j] == 'def':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit1_status,
                                                                            status_two=def_status)
                    if df.index[j] == 'tit1':
                        if i == 0 or i == 1 and df.iloc[i-1][j][-1] == '0':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit1_status,
                                                                                status_two=tit1_status)
                        else:
                            if df.iloc[i - 1][j][0] == '0':
                                if df.iloc[i - 2][j][0] == 'D':
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit1_status,
                                                                                        status_two='D')
                                else:
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit1_status,
                                                                                        status_two=tit1_status)
                            if df.iloc[i - 1][j][0] == 'D':
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit1_status,
                                                                                    status_two='D')
                            else:
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit1_status,
                                                                                    status_two=tit1_status)
                    if df.index[j] == 'tit0':
                        if i == 0 or i == 1 and df.iloc[i-1][j][-1] == '0':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit1_status,
                                                                                status_two='D')
                        elif df.iloc[i - 1][j][0] == '0' and df.iloc[i - 2][j][0] == 'D' or df.iloc[i - 1][j][0] == 'D':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit1_status,
                                                                                status_two='D')
                        else:
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit1_status,
                                                                                status_two=tit0_status)
                    if df.index[j] == 'disap':
                        if df.iloc[i - 2][j][0] == 'D' and df.iloc[i - 1][j][0] == 'D':
                            disap_status = 'D'
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit1_status,
                                                                            status_two=disap_status)
            # tit0
            if df.columns[i] == 'tit0':
                if j == 0 or j == 1 and df.iloc[i][j - 1][-1] == '0' \
                        or df.iloc[i][j - 1][0] == '0' and df.iloc[i][j - 2][-1] == 'D' or df.iloc[i][j - 1][-1] == 'D':
                    if df.index[j] == 'coop':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                            status_two=coop_status)
                    if df.index[j] == 'def':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                            status_two=def_status)
                    if df.index[j] == 'tit1':
                        if i == 0 or i == 1 and df.iloc[i - 1][j][-1] == '0':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                status_two=tit1_status)
                        else:
                            if df.iloc[i - 1][j][0] == '0':
                                if df.iloc[i - 2][j][0] == 'D':
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                        status_two=not tit1_status)
                                else:
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                        status_two=tit1_status)
                            if df.iloc[i - 1][j][0] == 'D':
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                    status_two='D')
                            else:
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                    status_two=tit1_status)
                    if df.index[j] == 'tit0':
                        if i == 0 or i == 1 and df.iloc[i - 1][j][-1] == 'D':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                status_two='D')
                        else:
                            if df.iloc[i - 1][j][0] == '0':
                                if df.iloc[i - 2][j][0] == 'D':
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                        status_two='D')
                                else:
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                        status_two=tit0_status)
                            if df.iloc[i - 1][j][0] == 'D':
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                    status_two='D')
                            else:
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                    status_two=tit0_status)
                    if df.index[j] == 'disap':
                        if df.iloc[i - 2][j][0] == 'D' and df.iloc[i - 1][j][0] == 'D':
                            disap_status = 'D'
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                            status_two=disap_status)
                else:
                    if df.index[j] == 'coop':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit0_status,
                                                                            status_two=coop_status)
                    if df.index[j] == 'def':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit0_status,
                                                                            status_two=def_status)
                    if df.index[j] == 'tit1':
                        if i == 0 or i == 1 and df.iloc[i - 1][j][-1] == '0':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit0_status,
                                                                                status_two=tit1_status)
                        else:
                            if df.iloc[i - 1][j][0] == '0':
                                if df.iloc[i - 2][j][0] == 'D':
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit0_status,
                                                                                        status_two='D')
                                else:
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit0_status,
                                                                                        status_two=tit1_status)
                            if df.iloc[i - 1][j][0] == 'D':
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit0_status,
                                                                                    status_two='D')
                            else:
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit0_status,
                                                                                    status_two=tit1_status)
                    if df.index[j] == 'tit0':
                        if i == 0 or i == 1 and df.iloc[i - 1][j][-1] == '0':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit0_status,
                                                                                status_two='D')
                        elif df.iloc[i - 1][j][0] == '0' and df.iloc[i - 2][j][0] == 'D' or df.iloc[i - 1][j][0] == 'D':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit0_status,
                                                                                status_two='D')
                        else:
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit0_status,
                                                                                status_two=tit0_status)
                    if df.index[j] == 'disap':
                        if df.iloc[i - 2][j][0] == 'D' and df.iloc[i - 1][j][0] == 'D':
                            disap_status = 'D'
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit0_status,
                                                                            status_two=disap_status)
            # disap
            if df.columns[i] == 'disap':
                if df.iloc[i][j - 2][-1] == 'D' and df.iloc[i][j - 1][-1] == 'D':
                    disap_status_horizon = 'D'
                if df.index[j] == 'coop':
                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=disap_status_horizon,
                                                                        status_two=coop_status)
                if df.index[j] == 'def':
                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=disap_status_horizon,
                                                                        status_two=def_status)
                if df.index[j] == 'tit1':
                    if df.iloc[i-1][j][-1] == '0' and df.iloc[i - 2][j][0] == 'D':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=disap_status_horizon,
                                                                            status_two='D')
                    if df.iloc[i - 1][j][0] == 'D':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=disap_status_horizon,
                                                                            status_two='D')
                    else:
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=disap_status_horizon,
                                                                            status_two=tit1_status)
                if df.index[j] == 'tit0':
                    if i == 0 or i == 1 and df.iloc[i-1][j][0] == '0':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=disap_status_horizon,
                                                                            status_two='D')
                    elif df.iloc[i - 1][j][0] == '0':
                        if df.iloc[i - 2][j][0] == 'D':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=disap_status_horizon,
                                                                                status_two='D')
                        else:
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=disap_status_horizon,
                                                                                status_two=tit0_status)
                    elif df.iloc[i - 1][j][0] == 'D':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=disap_status_horizon,
                                                                            status_two='D')
                    else:
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=disap_status_horizon,
                                                                            status_two=tit0_status)
                if df.index[j] == 'disap':
                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=disap_status_horizon,
                                                                        status_two=disap_status)

# %%
incentive = 4 # change if needed
U, L, C, P = 6, 3, 0, 0  # change if needed
df_payoff = df.copy()
for i in range(len(teachers)):
    for j in range(len(teachers)):
        if df_payoff.iloc[i][j] == '0, 0':
            df_payoff.iloc[i][j] = 0
        if df_payoff.iloc[i][j] == 'C, C':
            df_payoff.iloc[i][j] = U + C + incentive - L
        if df_payoff.iloc[i][j] == 'C, D':
            df_payoff.iloc[i][j] = incentive - L
        if df_payoff.iloc[i][j] == 'D, C':
            df_payoff.iloc[i][j] = U
        if df_payoff.iloc[i][j] == 'D, D':
            df_payoff.iloc[i][j] = P

# %%
df_payoff
# Out:
#      def coop tit0 tit1 coop tit0 coop tit0 tit1 tit0  ... tit0 tit1 tit0  \
# def    0    6    0    6    6    0    6    0    6    0  ...    0    6    0
# coop   1    0    1    1    7    1    7    1    1    1  ...    1    1    1
# tit0   0    6    0    7    7    7    7    7    7    7  ...    7    7    7
# tit1   1    6    7    0    7    7    7    7    7    7  ...    7    7    7
# coop   1    7    7    7    0    7    7    7    7    7  ...    7    7    7
# ...   ..  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# coop   1    7    7    7    7    7    7    7    7    7  ...    7    7    7
# def    0    6    6    6    6    6    6    6    6    6  ...    6    6    6
# def    0    6    0    0    6    0    6    0    0    0  ...    0    0    0
# def    0    6    0    0    6    0    6    0    0    0  ...    0    0    0
# tit0   0    6    1    0    6    1    6    1    0    0  ...    0    0    0
#
#      tit1 tit0 coop def def def tit0
# def     6    0    6   0   0   0    0
# coop    1    1    7   1   1   1    1
# tit0    7    7    7   1   0   0    6
# tit1    7    7    7   1   0   0    0
# coop    7    7    7   1   1   1    1
# ...   ...  ...  ...  ..  ..  ..  ...
# coop    7    7    0   1   1   1    1
# def     6    6    6   0   0   0    6
# def     0    0    6   0   0   0    0
# def     0    0    6   0   0   0    0
# tit0    0    0    6   1   0   0    0
#
# [100 rows x 100 columns]

# %%
# ploting the result
from matplotlib.font_manager import FontProperties

font = FontProperties()
font.set_family('serif')
font.set_name('Times New Roman')
font.set_style('italic')

data = df_payoff.groupby(df_payoff.index).sum()
fig, ax = plt.subplots(figsize=(18, 16), dpi= 80)
ax.set_title('Strategies Comparison (incentive=4)', fontsize=20) # change digit of incentive
ax.boxplot(data, labels=data.index)
ax.set_xlabel('Pay offs', fontsize='large', fontweight='bold')
ax.set_ylabel('Players', fontsize='large', fontproperties=font)
plt.show()
# Out:
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
